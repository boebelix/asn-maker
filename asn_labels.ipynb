# %% [markdown]
# # ASN Label Maker
# Erzeugt druckfertige ASN-Labels (30 × 15 mm) mit QR-Code.

# %%
# !uv pip install -q qrcode[pil] reportlab Pillow

# %%
# !wget -q https://raw.githubusercontent.com/boebelix/asn-maker/main/asn_labels.py

# %%
# --- Einstellungen ---
START   = 1      # erste Nummer
END     = 100    # letzte Nummer
REVERSE = True   # True = Rollen-Druck (Rolle beginnt bei 00001)
OUTPUT  = 'asn_labels.pdf'
# ---------------------

flag = '--reverse' if REVERSE else ''
# !python asn_labels.py {START} {END} {flag} -o {OUTPUT}

# %%
from google.colab import files
files.download(OUTPUT)
